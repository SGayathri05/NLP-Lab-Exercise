# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("/content/1000-source-results (2).xlsx",sheet_name="Sheet1")
data.head()
# Out:
#                                         Source title  CiteScore  \
# 0         Foundations and Trends in Machine Learning       91.4
# 1    International Journal of Information Management       41.9
# 2  Proceedings of the IEEE Computer Society Confe...       40.7
# 3    Foundations and Trends in Information Retrieval       38.9
# 4                                 Information Fusion       38.6
#
#                                   Highest percentile  2019-22 Citations  \
# 0                             99.0%\n1/404\nSoftware               1553
# 1  99.0%\n1/379\nComputer Networks and Communicat...              25458
# 2                             99.0%\n2/404\nSoftware             264109
# 3                  99.0%\n2/379\nInformation Systems                428
# 4            99.0%\n1/169\nHardware and Architecture              22011
#
#    2019-22 Documents  % Cited    SNIP     SJR            Publisher
# 0                 17       88  22.041  13.775  Now Publishers Inc.
# ...

# %%
data.isnull().sum()
# Out:
# Source title          0
# CiteScore             0
# Highest percentile    0
# 2019-22 Citations     0
# 2019-22 Documents     0
# % Cited               0
# SNIP                  0
# SJR                   0
# Publisher             2
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
# To sort values

data.sort_values("CiteScore")
# Out:
#                                          Source title  CiteScore  \
# 28  IEEE Transactions on Neural Networks and Learn...       21.9
# 26  Annual Review of Control, Robotics, and Autono...       22.3
# 27                   IEEE Transactions on Cybernetics       22.3
# 25        IEEE Transactions on Industrial Informatics       22.4
# 24                    IEEE Signal Processing Magazine       22.4
# 23                            Computer Science Review       22.4
# 22           International Journal of Computer Vision       22.5
# 21                                            AI Open       22.5
# 20                     Artificial Intelligence Review       23.0
# 19                               npj Digital Medicine       23.6
# 18                    IEEE Transactions on Smart Grid       23.6
# 17                            Computers and Education       23.8
# 16                                Journal of Big Data       23.9
# ...

# %%
sns.violinplot(data["CiteScore"],orient="v")
# Out:
# <Axes: >

# %%
sns.boxplot(data,orient="h")
# Out:
# <Axes: >

# %%
plt.scatter(data.index, data["CiteScore"])
plt.show()
